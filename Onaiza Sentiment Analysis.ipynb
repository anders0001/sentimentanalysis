# %%
#README

# PROCESS
#1. Download Twitter datasets via Get Old Tweets, Github: https://github.com/Jefferson-Henrique/GetOldTweets-python
#2. Delete all columns except for "date" & "text"
#3. Filter out 

#HASTAGS
#hashtag_1 = 'Lovejihadtapes'
#hashtag_2 = 'bannikahsex'
#hashtag_3 = 'lovejihadfight'
#hashtag_4 = 'CaliphateConvertsHindu'
#hashtag_5 = 'Lovejihadnailed'
#hashtag_6 = 'Lovejehadnexustapes'
#hashtag_7 = 'Hadiyaconversiontwist'
#hashtag_8 = 'Hadiyapfitrophy'

# %%
#Load libraries & datasets
import csv
import pandas as pd
import nltk

ht_lovejihadtapes = '/Users/andersfleck/Desktop/Data Science/Sentiment Analysis on Indian Racism/hashtag_lovejihadtapes.csv'
df = pd.read_csv(ht_lovejihadtapes, error_bad_lines=False)
df
# Out:
# b'Skipping line 28: expected 1 fields, saw 3\nSkipping line 30: expected 1 fields, saw 2\nSkipping line 35: expected 1 fields, saw 2\nSkipping line 38: expected 1 fields, saw 3\nSkipping line 49: expected 1 fields, saw 3\nSkipping line 56: expected 1 fields, saw 2\nSkipping line 68: expected 1 fields, saw 2\nSkipping line 74: expected 1 fields, saw 2\nSkipping line 98: expected 1 fields, saw 2\nSkipping line 106: expected 1 fields, saw 3\nSkipping line 109: expected 1 fields, saw 2\nSkipping line 112: expected 1 fields, saw 3\nSkipping line 113: expected 1 fields, saw 5\nSkipping line 116: expected 1 fields, saw 2\nSkipping line 118: expected 1 fields, saw 2\nSkipping line 119: expected 1 fields, saw 2\nSkipping line 136: expected 1 fields, saw 2\nSkipping line 140: expected 1 fields, saw 3\nSkipping line 147: expected 1 fields, saw 2\nSkipping line 164: expected 1 fields, saw 2\nSkipping line 165: expected 1 fields, saw 3\nSkipping line 167: expected 1 fields, saw 3\nSkipping line 1
# ...

# %%
#1: Data Cleansing
    #1. Separate Date & Time (Left & right formulae in Excel)
    #2.Find and replace with Excel: ‡,§,™,∞,®,æ,•,=
